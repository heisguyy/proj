# %%
# Import necessary libraries
import warnings
import pandas as pd
import numpy as np
from sklearn.preprocessing  import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import LeaveOneOut, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import optuna
np.random.seed(13)

warnings.filterwarnings("ignore")

# %%
# Import validated data
data = pd.read_csv("data/data_validated.csv")
medical_data = pd.read_csv("data/data_medic_validated.csv")

# %%
data.loc[data["feedback"].notnull()]
# Out:
#          username                                           comments  \
# 34        BBG1308  High speed scanners make quick work of this.\n...
# 56  Averycooldood  I hope this is not rude to VTs, but as a VA I’...
#
#           labels                                           feedback
# 34  veterinarian  should be "other" this person sounds like a ve...
# 56  veterinarian    should be "other" VA means vetinarian assistant

# %%
# change reviewed columns
data.loc[data[data["feedback"].notnull()].index,"labels"] = "other"

# %%
data.loc[data["feedback"].notnull()]
# Out:
#          username                                           comments labels  \
# 34        BBG1308  High speed scanners make quick work of this.\n...  other
# 56  Averycooldood  I hope this is not rude to VTs, but as a VA I’...  other
#
#                                              feedback
# 34  should be "other" this person sounds like a ve...
# 56    should be "other" VA means vetinarian assistant

# %%
data["labels"].value_counts()
# Out:
# labels
# other             240
# veterinarian       56
# medical doctor      4
# Name: count, dtype: int64

# %%
# drop unnecessary samples with other labels
rows_to_drop = data.loc[data["labels"] == "other"].sample(200).index
data.drop(index=rows_to_drop, inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#              username                                           comments  \
# 0         HiddenJindo  Hello! Veterinary medicine is an incredibly re...
# 1  rotten-cheese-ball  I’ve taken a nationally administered exam befo...
# 2    Im-just-guessing  Removing dewclaws? No I agree with you, realis...
# 3           bilbany12  I'm a dentist and I respect vets more than hum...
# 4           robino358  My only concern with that would be if any inte...
#
#          labels feedback
# 0  veterinarian      NaN
# 1         other      NaN
# 2  veterinarian      NaN
# 3         other      NaN
# 4  veterinarian      NaN

# %%
medical_data.head(10)
# Out:
#                username                                           comments  \
# 0        No_Cellist_746  Hi! I am in my first year out of school and yo...
# 1            raygunlock  This behavior is so unacceptable. Please don’t...
# 2         heretoroastmk  Your salary feels on par for my classmates goi...
# 3   ReindeerVarious3024  I’m a human doctor who has fostered many a dog...
# 4               Kirsten  My sister is a veterinarian and I am a physici...
# 5  Prestigious_Union_50  I'm not excusing it ...but it's often a strain...
# 6      dedcrypticginger  It does include a LOT of on call cases/hours/w...
# 7            Amythyst72  Female, medical oncologist in CA. HCOL area. B...
# 8                DrZefe  Best job in the world IMO. But it’s not for ev...
# 9        unbuhhlievable  Do not let people gaslight you into thinking y...
#
#            labels                                           feedback
# 0  medical doctor                          this is the correct label
# 1  medical doctor                          this is the correct label
# 2  medical doctor                          this is the correct label
# 3  medical doctor                          this is the correct label
# 4  medical doctor                          this is the correct label
# 5  medical doctor                          this is the correct label
# 6  medical doctor                          this is the correct label
# 7  medical doctor                          this is the correct label
# 8  medical doctor                          this is the correct label
# 9  medical doctor  im unsure on this one. "tech" is usually for "...

# %%
# Drop last row because of uncertainty
medical_data.drop(index=[9],inplace=True)

# %%
medical_data.head(10)
# Out:
#                username                                           comments  \
# 0        No_Cellist_746  Hi! I am in my first year out of school and yo...
# 1            raygunlock  This behavior is so unacceptable. Please don’t...
# 2         heretoroastmk  Your salary feels on par for my classmates goi...
# 3   ReindeerVarious3024  I’m a human doctor who has fostered many a dog...
# 4               Kirsten  My sister is a veterinarian and I am a physici...
# 5  Prestigious_Union_50  I'm not excusing it ...but it's often a strain...
# 6      dedcrypticginger  It does include a LOT of on call cases/hours/w...
# 7            Amythyst72  Female, medical oncologist in CA. HCOL area. B...
# 8                DrZefe  Best job in the world IMO. But it’s not for ev...
#
#            labels                   feedback
# 0  medical doctor  this is the correct label
# 1  medical doctor  this is the correct label
# 2  medical doctor  this is the correct label
# 3  medical doctor  this is the correct label
# 4  medical doctor  this is the correct label
# 5  medical doctor  this is the correct label
# 6  medical doctor  this is the correct label
# 7  medical doctor  this is the correct label
# 8  medical doctor  this is the correct label

# %%
data.head()
# Out:
#              username                                           comments  \
# 0         HiddenJindo  Hello! Veterinary medicine is an incredibly re...
# 1  rotten-cheese-ball  I’ve taken a nationally administered exam befo...
# 2    Im-just-guessing  Removing dewclaws? No I agree with you, realis...
# 3           bilbany12  I'm a dentist and I respect vets more than hum...
# 4           robino358  My only concern with that would be if any inte...
#
#          labels feedback
# 0  veterinarian      NaN
# 1         other      NaN
# 2  veterinarian      NaN
# 3         other      NaN
# 4  veterinarian      NaN

# %%
medical_data.head()
# Out:
#               username                                           comments  \
# 0       No_Cellist_746  Hi! I am in my first year out of school and yo...
# 1           raygunlock  This behavior is so unacceptable. Please don’t...
# 2        heretoroastmk  Your salary feels on par for my classmates goi...
# 3  ReindeerVarious3024  I’m a human doctor who has fostered many a dog...
# 4              Kirsten  My sister is a veterinarian and I am a physici...
#
#            labels                   feedback
# 0  medical doctor  this is the correct label
# 1  medical doctor  this is the correct label
# 2  medical doctor  this is the correct label
# 3  medical doctor  this is the correct label
# 4  medical doctor  this is the correct label

# %%
# Drop unnecessary columns
columns_to_drop = ["feedback","username"]

data.drop(columns=columns_to_drop,inplace=True)
medical_data.drop(columns=columns_to_drop,inplace=True)

# %%
# Merge data with sourced medical data
data = pd.concat([data,medical_data],ignore_index=True)

# %%
# Saved training data
data.to_csv("data/training_data.csv",index=False)

# %%
data["labels"].value_counts()
# Out:
# labels
# veterinarian      56
# other             40
# medical doctor    13
# Name: count, dtype: int64

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(data["labels"])

# %%
bow_encoder = CountVectorizer(
    stop_words="english", dtype="float32"
)
X = bow_encoder.fit_transform(data["comments"])

# %%
# Get quick baselines for the models
model = {
    "LR": LogisticRegression(),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(random_state=42),
    "LGBM": LGBMClassifier(random_state=42,verbose= -1),
    "XGB": XGBClassifier(random_state=42),
}
loocv = LeaveOneOut()
for name, clf in model.items():
    scores = cross_val_score(clf,X,y,cv=loocv,scoring="accuracy")
    print(name)
    print(f"LOOCV Accuracy: {scores.mean()}")
    print("--------")
# Out:
# LR
# LOOCV Accuracy: 0.6788990825688074
# --------
# DT
# LOOCV Accuracy: 0.7798165137614679
# --------
# RF
# LOOCV Accuracy: 0.6330275229357798
# --------
# LGBM
# LOOCV Accuracy: 0.6330275229357798
# --------
# XGB
# LOOCV Accuracy: 0.7339449541284404
# --------

# %%
# Finetune best performing model, Decision Tree with optuna
def decision_tree_trial(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5),
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy","log_loss"])
    }
    clf = DecisionTreeClassifier(**params)
    score = cross_val_score(clf,X,y,cv=loocv,scoring="accuracy").mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(decision_tree_trial, n_trials=100)
# Out:
# [I 2024-05-16 22:51:13,534] A new study created in memory with name: no-name-6774e716-2ac3-46a6-ab3e-10b46c3c1c1a
# [I 2024-05-16 22:51:13,780] Trial 0 finished with value: 0.6880733944954128 and parameters: {'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 0 with value: 0.6880733944954128.
# [I 2024-05-16 22:51:14,101] Trial 1 finished with value: 0.7614678899082569 and parameters: {'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 3, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.7614678899082569.
# [I 2024-05-16 22:51:14,307] Trial 2 finished with value: 0.6422018348623854 and parameters: {'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 1 with value: 0.7614678899082569.
# [I 2024-05-16 22:51:14,645] Trial 3 finished with value: 0.7247706422018348 and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7614678899082569.
# [I 2024-05-16 22:51:14,973] Trial 4 finished with value: 0.7614678899082569 and parameters: {'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 5, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.7614678899082569.
# [I 2024-05-16 22:51:15,386] Trial 5 finished with value: 0.8073394495412844 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:15,692] Trial 6 finished with value: 0.7247706422018348 and parameters: {'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'log_loss'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:16,035] Trial 7 finished with value: 0.7614678899082569 and parameters: {'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:16,345] Trial 8 finished with value: 0.6972477064220184 and parameters: {'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:16,649] Trial 9 finished with value: 0.7981651376146789 and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'log_loss'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:17,095] Trial 10 finished with value: 0.8073394495412844 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:17,507] Trial 11 finished with value: 0.8073394495412844 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:17,930] Trial 12 finished with value: 0.7981651376146789 and parameters: {'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:18,301] Trial 13 finished with value: 0.8073394495412844 and parameters: {'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:18,679] Trial 14 finished with value: 0.7522935779816514 and parameters: {'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:19,065] Trial 15 finished with value: 0.7706422018348624 and parameters: {'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:19,494] Trial 16 finished with value: 0.7889908256880734 and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:19,864] Trial 17 finished with value: 0.7889908256880734 and parameters: {'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:20,321] Trial 18 finished with value: 0.7798165137614679 and parameters: {'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:20,734] Trial 19 finished with value: 0.7889908256880734 and parameters: {'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:21,158] Trial 20 finished with value: 0.7798165137614679 and parameters: {'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:21,586] Trial 21 finished with value: 0.7981651376146789 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:21,991] Trial 22 finished with value: 0.7981651376146789 and parameters: {'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:22,368] Trial 23 finished with value: 0.7522935779816514 and parameters: {'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:22,789] Trial 24 finished with value: 0.7981651376146789 and parameters: {'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:23,159] Trial 25 finished with value: 0.7798165137614679 and parameters: {'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:23,583] Trial 26 finished with value: 0.7706422018348624 and parameters: {'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:23,899] Trial 27 finished with value: 0.7522935779816514 and parameters: {'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:24,306] Trial 28 finished with value: 0.7798165137614679 and parameters: {'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:24,790] Trial 29 finished with value: 0.8073394495412844 and parameters: {'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:25,310] Trial 30 finished with value: 0.7889908256880734 and parameters: {'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:25,687] Trial 31 finished with value: 0.7614678899082569 and parameters: {'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:26,059] Trial 32 finished with value: 0.7614678899082569 and parameters: {'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:26,482] Trial 33 finished with value: 0.8073394495412844 and parameters: {'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:26,823] Trial 34 finished with value: 0.7247706422018348 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 5 with value: 0.8073394495412844.
# [I 2024-05-16 22:51:27,277] Trial 35 finished with value: 0.8165137614678899 and parameters: {'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:27,769] Trial 36 finished with value: 0.8073394495412844 and parameters: {'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:28,232] Trial 37 finished with value: 0.7798165137614679 and parameters: {'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:28,558] Trial 38 finished with value: 0.7339449541284404 and parameters: {'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:29,026] Trial 39 finished with value: 0.7981651376146789 and parameters: {'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:29,405] Trial 40 finished with value: 0.7155963302752294 and parameters: {'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:29,794] Trial 41 finished with value: 0.7706422018348624 and parameters: {'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:30,236] Trial 42 finished with value: 0.8073394495412844 and parameters: {'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:30,580] Trial 43 finished with value: 0.7614678899082569 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:30,968] Trial 44 finished with value: 0.7706422018348624 and parameters: {'max_depth': 19, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:31,423] Trial 45 finished with value: 0.7706422018348624 and parameters: {'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:31,778] Trial 46 finished with value: 0.6972477064220184 and parameters: {'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:32,258] Trial 47 finished with value: 0.8073394495412844 and parameters: {'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:32,652] Trial 48 finished with value: 0.7339449541284404 and parameters: {'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:33,039] Trial 49 finished with value: 0.7889908256880734 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:33,504] Trial 50 finished with value: 0.7706422018348624 and parameters: {'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:34,043] Trial 51 finished with value: 0.8073394495412844 and parameters: {'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:34,577] Trial 52 finished with value: 0.7981651376146789 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:35,076] Trial 53 finished with value: 0.8073394495412844 and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 35 with value: 0.8165137614678899.
# [I 2024-05-16 22:51:35,604] Trial 54 finished with value: 0.8256880733944955 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:36,137] Trial 55 finished with value: 0.8165137614678899 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:36,718] Trial 56 finished with value: 0.8073394495412844 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:37,223] Trial 57 finished with value: 0.8165137614678899 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:37,732] Trial 58 finished with value: 0.8165137614678899 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:38,078] Trial 59 finished with value: 0.7522935779816514 and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:38,534] Trial 60 finished with value: 0.8073394495412844 and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:39,028] Trial 61 finished with value: 0.8165137614678899 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:39,500] Trial 62 finished with value: 0.8165137614678899 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 54 with value: 0.8256880733944955.
# [I 2024-05-16 22:51:39,974] Trial 63 finished with value: 0.8348623853211009 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:40,439] Trial 64 finished with value: 0.7798165137614679 and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:40,888] Trial 65 finished with value: 0.7981651376146789 and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:41,195] Trial 66 finished with value: 0.7522935779816514 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:41,642] Trial 67 finished with value: 0.7798165137614679 and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:42,125] Trial 68 finished with value: 0.7981651376146789 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:42,604] Trial 69 finished with value: 0.8073394495412844 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:42,893] Trial 70 finished with value: 0.6788990825688074 and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:43,381] Trial 71 finished with value: 0.8165137614678899 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:43,896] Trial 72 finished with value: 0.8256880733944955 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:44,409] Trial 73 finished with value: 0.8256880733944955 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:44,963] Trial 74 finished with value: 0.7889908256880734 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:45,467] Trial 75 finished with value: 0.8165137614678899 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:45,866] Trial 76 finished with value: 0.7706422018348624 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.8348623853211009.
# [I 2024-05-16 22:51:46,332] Trial 77 finished with value: 0.8440366972477065 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:46,814] Trial 78 finished with value: 0.8256880733944955 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:47,310] Trial 79 finished with value: 0.8073394495412844 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:47,680] Trial 80 finished with value: 0.7981651376146789 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:48,149] Trial 81 finished with value: 0.8165137614678899 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:48,588] Trial 82 finished with value: 0.8073394495412844 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:49,061] Trial 83 finished with value: 0.8256880733944955 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:49,574] Trial 84 finished with value: 0.8165137614678899 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:50,086] Trial 85 finished with value: 0.8073394495412844 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:50,643] Trial 86 finished with value: 0.8165137614678899 and parameters: {'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:51,197] Trial 87 finished with value: 0.7981651376146789 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:51,733] Trial 88 finished with value: 0.7981651376146789 and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:52,251] Trial 89 finished with value: 0.8073394495412844 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:52,647] Trial 90 finished with value: 0.7798165137614679 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:53,174] Trial 91 finished with value: 0.7981651376146789 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:53,712] Trial 92 finished with value: 0.8073394495412844 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:54,246] Trial 93 finished with value: 0.8440366972477065 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:54,791] Trial 94 finished with value: 0.7889908256880734 and parameters: {'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:55,330] Trial 95 finished with value: 0.8073394495412844 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:55,874] Trial 96 finished with value: 0.8073394495412844 and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:56,427] Trial 97 finished with value: 0.7798165137614679 and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:56,941] Trial 98 finished with value: 0.7981651376146789 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.
# [I 2024-05-16 22:51:57,437] Trial 99 finished with value: 0.8256880733944955 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}. Best is trial 77 with value: 0.8440366972477065.

# %%
# Get best performing parameters
trial = study.best_trial

print(f"Best Parameters: {trial.params}")
print(f"Best Score: {trial.value}")
# Out:
# Best Parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'log_loss'}
# Best Score: 0.8440366972477065
